# %% [markdown]
# ## <span style="color:red">*Exercise 1*</span>
#
# <span style="color:red">Construct cells immediately below this that embed documents related to your final project using at least two different specification of `word2vec`, and visualize them each with two separate visualization layout specifications (e.g., TSNE, PCA). Then interrogate critical word vectors within your corpus in terms of the most similar words, analogies, and other additions and subtractions that reveal the structure of similarity and difference within your semantic space. What does this pattern reveal about the semantic organization of words in your corpora? Which estimation and visualization specification generate the most insight and appear the most robustly supported and why?
#
# <span style="color:red">***Stretch***: Explore different vector calculations beyond addition and subtraction, such as multiplication, division or some other function. What does this exploration reveal about the semantic structure of your corpus?

# %%
#All these packages need to be installed from pip
import gensim#For word2vec, etc
import requests #For downloading our datasets
import lucem_illud_2020 #pip install -U git+git://github.com/UChicago-Computational-Content-Analysis/lucem_illud.git

import numpy as np #For arrays
import pandas #Gives us DataFrames
import matplotlib.pyplot as plt #For graphics
import seaborn #Makes the graphics look nicer
import sklearn.metrics.pairwise #For cosine similarity
import sklearn.manifold #For T-SNE
import sklearn.decomposition #For PCA

#This 'magic' command makes the plots work better
#in the notebook, don't use it outside of a notebook.
#Also you can ignore the warning
# %matplotlib inline

import os #For looking through files
import os.path #For managing file paths

# %%
#importing normalized data from wek 5
import pickle
with open('../week-5/text_by_dec.pickle', 'rb') as handle:
    df2 = pickle.load(handle)

# %%
df2.head()
# Out:
#                 Decision                                              Texts  \
# 0  decisions/cp1/1-1.pdf  FCCC/CP/1995/7/Add.1EnglishPage 4I.  DECISIONS...
# 1  decisions/cp1/1-2.pdf  FCCC/CP/1995/7/Add.1EnglishPage 7Decision 2/CP...
# 2  decisions/cp1/1-3.pdf  FCCC/CP/1995/7/Add.1EnglishPage 13Decision 3/C...
# 3  decisions/cp1/1-4.pdf  FCCC/CP/1995/7/Add.1EnglishPage 15Decision 4/C...
# 4  decisions/cp1/1-5.pdf  FCCC/CP/1995/7/Add.1EnglishPage 18Decision 5/C...
#
#                                      tokenized_sents  \
# 0  [[FCCC/], [CP/1995/7], [/Add.1EnglishPage], [4...
# 1  [[FCCC/], [CP/1995/7], [/Add.1EnglishPage, 7De...
# 2  [[FCCC/], [CP/1995/7/], [Add.1EnglishPage, 13D...
# 3  [[FCCC/], [CP/1995/7, Add.1EnglishPage, 15Deci...
# 4  [[FCCC/], [CP/1995/7/], [Add.1EnglishPage, 18D...
#
#                                     normalized_sents
# 0  [[fccc/], [cp/1995/7], [/add.1englishpage], [4...
# 1  [[fccc/], [cp/1995/7], [/add.1englishpage, 7de...
# ...

# %% [markdown]
# #### 1. CBOW

# %%
import time 
start = time.time()
W2V = gensim.models.word2vec.Word2Vec(df['normalized_sents'].sum())
print ('time elapsed:', time.time()-start)
# Out:
# time elapsed: 3.74127197265625

# %%
import time 
start = time.time()
W2V2 = gensim.models.word2vec.Word2Vec(df2['normalized_sents'].sum(), window = 10)
print ('time elapsed:', time.time()-start)
# Out:
# time elapsed: 3.2997679710388184

# %%
import time 
start = time.time()
W2V2 = gensim.models.word2vec.Word2Vec(df2['normalized_sents'].sum(), window = 20)
print ('time elapsed:', time.time()-start)
# Out:
# time elapsed: 3.1825599670410156

# %%
W2V.most_similar('transparency')
# Out:
# [('improve', 0.8693474531173706),
#  ('effectiveness', 0.8596128821372986),
#  ('order', 0.8242185115814209),
#  ('exist', 0.7958213090896606),
#  ('aim', 0.7954412698745728),
#  ('manner', 0.7898907661437988),
#  ('comparability', 0.7891017198562622),
#  ('\uf0b7', 0.785405158996582),
#  ('clarity', 0.7783211469650269),
#  ('ensure', 0.7621967792510986)]

# %%
start = time.time()
W2V2 = gensim.models.word2vec.Word2Vec(df2['normalized_sents'].sum(), window = 2)
print ('time elapsed:', time.time()-start)
# Out:
# time elapsed: 2.8117780685424805

# %%
W2V.most_similar('compliance')
# Out:
# [('supervisory', 0.7864246368408203),
#  ('paris', 0.7832938432693481),
#  ('reliableinformation', 0.756212592124939),
#  ('reliable', 0.6911031007766724),
#  ('transitional', 0.6391751170158386),
#  ('workplan', 0.6383388042449951),
#  ('article', 0.6377753019332886),
#  ('agreement', 0.6346009969711304),
#  ('shall', 0.6344206929206848),
#  ('matter', 0.6290943622589111)]

# %%
W2V.most_similar('adaptation')
# Out:
# [('action', 0.7523963451385498),
#  ('prioritize', 0.7465792894363403),
#  ('formulate', 0.7216852307319641),
#  ('formulation', 0.7193634510040283),
#  ('strategic', 0.7076979875564575),
#  ('context', 0.7019541263580322),
#  ('integrate', 0.7005234360694885),
#  ('priority', 0.6918302178382874),
#  ('plan', 0.6884667873382568),
#  ('strategy', 0.6863923072814941)]

# %%
W2V.most_similar('mitigation')
# Out:
# [('context', 0.7644425630569458),
#  ('ambition', 0.7601782083511353),
#  ('track', 0.7508741021156311),
#  ('strategy', 0.7479371428489685),
#  ('relation', 0.7393174171447754),
#  ('option', 0.7377239465713501),
#  ('nationally', 0.7334685325622559),
#  ('stage', 0.7241110801696777),
#  ('\uf0b7', 0.7219834327697754),
#  ('approach', 0.7027535438537598)]

# %%
W2V.most_similar('transfer')
# Out:
# [('sound', 0.7716067433357239),
#  ('environmentally', 0.7647205591201782),
#  ('diffusion', 0.7521772980690002),
#  ('deployment', 0.749253511428833),
#  ('endogenous', 0.7290244698524475),
#  ('know', 0.7261245250701904),
#  ('secretariat:(a)to', 0.712909460067749),
#  ('accelerate', 0.6983590126037598),
#  ('technology', 0.6820135712623596),
#  ('ofenvironmentally', 0.6812498569488525)]

# %%
W2V.most_similar('capacity')
# Out:
# [('confidence', 0.7669339776039124),
#  ('exist', 0.6934646368026733),
#  ('transparency', 0.6134176254272461),
#  ('coordination', 0.595086932182312),
#  ('framework', 0.5866619944572449),
#  ('opportunity', 0.5786590576171875),
#  ('need', 0.576796293258667),
#  ('effectiveness', 0.5703117847442627),
#  ('strengthen', 0.5658487677574158),
#  ('support', 0.5586923360824585)]

# %%
W2V.most_similar('effectiveness')
# Out:
# [('improve', 0.89378821849823),
#  ('evaluate', 0.8847222328186035),
#  ('transparency', 0.8596128821372986),
#  ('exist', 0.8572810888290405),
#  ('aim', 0.8552701473236084),
#  ('order', 0.8437738418579102),
#  ('coordination', 0.8331891894340515),
#  ('\uf0b7', 0.8278762102127075),
#  ('effective', 0.8120726943016052),
#  ('promote', 0.8101617693901062)]

# %%
W2V.most_similar('obligation')
# Out:
# [('3–5', 0.7757844924926758),
#  ('theconvention', 0.7654532790184021),
#  ('agreement', 0.7587027549743652),
#  ('eligible', 0.7550888061523438),
#  ('comply', 0.7395451068878174),
#  ('inscribe', 0.7387914657592773),
#  ('incur', 0.7251818180084229),
#  ('effectively', 0.720796525478363),
#  ('4.2(b', 0.7207518815994263),
#  ('reach', 0.7098413705825806)]

# %%
W2V.most_similar('contribution')
# Out:
# [('voluntary', 0.808363139629364),
#  ('core', 0.7944538593292236),
#  ('pay', 0.7588028907775879),
#  ('kind', 0.7103641033172607),
#  ('determine', 0.7079120874404907),
#  ('pledge', 0.6956619024276733),
#  ('indicative', 0.6954649686813354),
#  ('bear', 0.6880170106887817),
#  ('eur', 0.6840629577636719),
#  ('mind', 0.6740267276763916)]

# %%
W2V.most_similar('annex')
# Out:
# [('inannex', 0.8277563452720642),
#  ('ii', 0.7348765134811401),
#  ('nationalcommunications', 0.7156407237052917),
#  ('communicationsfrom', 0.664436936378479),
#  ('iii', 0.6510763168334961),
#  ('initial', 0.645342230796814),
#  ('communication', 0.645056962966919),
#  ('fromparties', 0.6349414587020874),
#  ('includedin', 0.6331794261932373),
#  ('notincluded', 0.6251471042633057)]

# %%
W2V.most_similar('finance')
# Out:
# [('flow', 0.7919913530349731),
#  ('mobilize', 0.7692445516586304),
#  ('access', 0.7249523401260376),
#  ('investment', 0.7117912769317627),
#  ('centre', 0.7020310759544373),
#  ('delivery', 0.6880914568901062),
#  ('technology', 0.684104323387146),
#  ('leverage', 0.6795461773872375),
#  ('mobilization', 0.6786720752716064),
#  ('channel', 0.6705433130264282)]

# %%
W2V.most_similar('ndc')
# Out:
# [('quantitative', 0.885138213634491),
#  ('separately', 0.8838002681732178),
#  ('series', 0.8702199459075928),
#  ('compare', 0.866526186466217),
#  ('technically', 0.8636353015899658),
#  ('disaggregation', 0.8625405430793762),
#  ('qualitative', 0.8557478785514832),
#  ('unadjusted', 0.8555465936660767),
#  ('actual', 0.8549561500549316),
#  ('comparison', 0.8512852191925049)]

# %%
W2V.most_similar('information')
# Out:
# [('report', 0.7223610877990723),
#  ('detail', 0.7187964916229248),
#  ('datum', 0.6889857053756714),
#  ('provide', 0.6713860034942627),
#  ('bur', 0.668969988822937),
#  ('confidential', 0.6623409986495972),
#  ('analysis', 0.6549308896064758),
#  ('paper', 0.6534117460250854),
#  ('archive', 0.6524667739868164),
#  ('synthesis', 0.6498419046401978)]

# %%
W2V.most_similar(positive=['improve', 'adaptation'], negative = ['transparency'])
# Out:
# [('integrate', 0.7978836297988892),
#  ('focus', 0.7139856815338135),
#  ('gender', 0.6962965726852417),
#  ('observation', 0.6874269247055054),
#  ('prioritize', 0.6841169595718384),
#  ('response', 0.6834970116615295),
#  ('strategic', 0.6814937591552734),
#  ('ongoing', 0.6788361072540283),
#  ('research', 0.674258828163147),
#  ('aspect', 0.6690335273742676)]

# %%
W2V.most_similar(positive=['improve', 'mitigation'], negative = ['transparency'])
# Out:
# [('vulnerability', 0.7676252126693726),
#  ('approach', 0.7608071565628052),
#  ('track', 0.7583109140396118),
#  ('integrate', 0.7496902942657471),
#  ('significant', 0.7293705344200134),
#  ('strategy', 0.722410261631012),
#  ('benefit', 0.7180328369140625),
#  ('demonstration', 0.7168444991111755),
#  ('environmental', 0.7084674835205078),
#  ('barrier', 0.6940292119979858)]

# %%
W2V.most_similar(positive=['improve', 'technology'], negative = ['transparency'])
# Out:
# [('network', 0.7900558710098267),
#  ('environmentally', 0.7474094033241272),
#  ('sound', 0.7450958490371704),
#  ('know', 0.735512912273407),
#  ('centre', 0.7302317023277283),
#  ('clear', 0.7112365961074829),
#  ('ofenvironmentally', 0.7079729437828064),
#  ('house', 0.6999334096908569),
#  ('research', 0.6824991703033447),
#  ('collaboration', 0.656437873840332)]

# %%
W2V.most_similar(positive=['transfer', 'information'], negative = ['technology'])
# Out:
# [('consistent', 0.5469328761100769),
#  ('database', 0.5224785804748535),
#  ('problem', 0.5173047780990601),
#  ('inventory', 0.5041068196296692),
#  ('section', 0.5026112794876099),
#  ('accurate', 0.5024507641792297),
#  ('consistency', 0.4957195818424225),
#  ('previously', 0.49423569440841675),
#  ('datum', 0.48989278078079224),
#  ('part', 0.48622024059295654)]

# %%
W2V.most_similar(positive=['transfer', 'transparency'], negative = ['technology'])
# Out:
# [('objective', 0.665008008480072),
#  ('aim', 0.6391538381576538),
#  ('comparability', 0.6386775374412537),
#  ('nationally', 0.6176620721817017),
#  ('order', 0.6161815524101257),
#  ('clarity', 0.608151912689209),
#  ('transparent', 0.6032704710960388),
#  ('target', 0.603089451789856),
#  ('achievement', 0.602342963218689),
#  ('progressively', 0.6008036136627197)]

# %%
W2V.most_similar(positive=['mitigation', 'transparency'], negative = ['adaptation'])
# Out:
# [('target', 0.7200229167938232),
#  ('\uf0b7', 0.7036128640174866),
#  ('consistency', 0.7028090953826904),
#  ('option', 0.6892144083976746),
#  ('ambition', 0.6882395148277283),
#  ('comparability', 0.678860068321228),
#  ('nationally', 0.6755508184432983),
#  ('improve', 0.6592168807983398),
#  ('clarity', 0.6485507488250732),
#  ('achieve', 0.6432132720947266)]

# %%
W2V.most_similar(positive=['promote', 'transparency'], negative = ['effectiveness'])
# Out:
# [('enhance', 0.8077199459075928),
#  ('order', 0.7906852960586548),
#  ('cooperation', 0.7902478575706482),
#  ('strengthen', 0.776016116142273),
#  ('manner', 0.7752888202667236),
#  ('importance', 0.7696783542633057),
#  ('coordination', 0.7528277635574341),
#  ('facilitate', 0.7477497458457947),
#  ('exist', 0.7459070682525635),
#  ('emphasize', 0.7437995672225952)]

# %%
W2V.most_similar(positive=['promote', 'information'], negative = ['effectiveness'])
# Out:
# [('mean', 0.6290011405944824),
#  ('provide', 0.6005297303199768),
#  ('exchange', 0.5833132863044739),
#  ('encourage', 0.5832209587097168),
#  ('explanation', 0.5831485390663147),
#  ('sector', 0.5705283880233765),
#  ('nir', 0.5696661472320557),
#  ('aspect', 0.5627100467681885),
#  ('relevant', 0.5623922944068909),
#  ('non', 0.5576764345169067)]

# %%
W2V.most_similar(positive=['promote', 'technology'], negative = ['effectiveness'])
# Out:
# [('network', 0.7617849707603455),
#  ('environmentally', 0.7432016134262085),
#  ('sound', 0.7386795282363892),
#  ('ofenvironmentally', 0.734183669090271),
#  ('know', 0.7046256065368652),
#  ('development', 0.6923848390579224),
#  ('deployment', 0.6796770095825195),
#  ('cooperation', 0.6752613186836243),
#  ('clear', 0.6716786623001099),
#  ('centre', 0.6715314388275146)]

# %%
W2V.most_similar(positive=['promote', 'transparency'], negative = ['effectiveness'])
# Out:
# [('enhance', 0.8077199459075928),
#  ('order', 0.7906852960586548),
#  ('cooperation', 0.7902478575706482),
#  ('strengthen', 0.776016116142273),
#  ('manner', 0.7752888202667236),
#  ('importance', 0.7696783542633057),
#  ('coordination', 0.7528277635574341),
#  ('facilitate', 0.7477497458457947),
#  ('exist', 0.7459070682525635),
#  ('emphasize', 0.7437995672225952)]

# %%
W2V.most_similar(positive=['promote', 'coordination'], negative = ['effectiveness'])
# Out:
# [('cooperation', 0.9449199438095093),
#  ('synergy', 0.8753228187561035),
#  ('strengthen', 0.870577335357666),
#  ('engagement', 0.8654390573501587),
#  ('coherence', 0.8604998588562012),
#  ('initiative', 0.8525139093399048),
#  ('institution', 0.8440464735031128),
#  ('involvement', 0.8314824104309082),
#  ('engage', 0.8228808045387268),
#  ('collaboration', 0.8163036108016968)]

# %% [markdown]
# #### 2. Skip gram

# %%
start = time.time()
W2V_skip = gensim.models.word2vec.Word2Vec(df['normalized_sents'].sum(), sg=1, window=10)
print ('time elapsed:', time.time()-start)
# Out:
# time elapsed: 6.157613754272461

# %%
start = time.time()
W2V_skip_w3 = gensim.models.word2vec.Word2Vec(df['normalized_sents'].sum(), sg=1, window=3)
print ('time elapsed:', time.time()-start)
# Out:
# time elapsed: 4.306654930114746

# %%
start = time.time()
W2V_skip_w20 = gensim.models.word2vec.Word2Vec(df['normalized_sents'].sum(), sg=1, window=20)
print ('time elapsed:', time.time()-start)
# Out:
# time elapsed: 10.148324728012085

# %% [markdown]
# #### 3. Visualization

# %%
#Using PCA and TSNE specification for visualization.
numWords = 100
targetWords = W2V.wv.index2word[:numWords]

wordsSubMatrix = []
for word in targetWords:
    wordsSubMatrix.append(W2V[word])
    
wordsSubMatrix = np.array(wordsSubMatrix)

pcaWords = sklearn.decomposition.PCA(n_components = 100).fit(wordsSubMatrix)
reducedPCA_data = pcaWords.transform(wordsSubMatrix)

#T-SNE is theoretically better, but you should experiment
tsneWords = sklearn.manifold.TSNE(n_components = 2).fit_transform(reducedPCA_data)

# %%
fig = plt.figure(figsize = (10,6))
ax = fig.add_subplot(111)
ax.set_frame_on(False)
plt.scatter(tsneWords[:, 0], tsneWords[:, 1], alpha = 0)#Making the points invisible 
for i, word in enumerate(targetWords):
    ax.annotate(word, (tsneWords[:, 0][i],tsneWords[:, 1][i]), size =  20 * (numWords - i) / numWords)
plt.xticks(())
plt.yticks(())
plt.show()

# %%
#Another visualization using incremental PCA
IncrePcaWords = sklearn.decomposition.IncrementalPCA(n_components = 100).fit(wordsSubMatrix)
reducedPCA_data = IncrePcaWords.transform(wordsSubMatrix)
#And use Locally Linear Embeddings...
tsneWords = sklearn.manifold.LocallyLinearEmbedding(n_components = 2).fit_transform(reducedPCA_data)

# %%
#Plot it
fig = plt.figure(figsize = (10,6))
ax = fig.add_subplot(111)
ax.set_frame_on(False)
plt.scatter(tsneWords[:, 0], tsneWords[:, 1], alpha = 0)#Making the points invisible 
for i, word in enumerate(targetWords):
    ax.annotate(word, (tsneWords[:, 0][i],tsneWords[:, 1][i]), size =  20 * (numWords - i) / numWords)
plt.xticks(())
plt.yticks(())
plt.show()

# %% [markdown]
# ## <span style="color:red">*Exercise 2*</span>
#
# <span style="color:red">Construct cells immediately below this that embed documents related to your final project using `doc2vec`, and explore the relationship between different documents and the word vectors you analyzed in the last exercise. Consider the most similar words to critical documents, analogies (doc _x_ + word _y_), and other additions and subtractions that reveal the structure of similarity and difference within your semantic space. What does this pattern reveal about the documentary organization of your semantic space?

# %%
import pickle
with open('../week-5/text_by_dec_raw.pickle', 'rb') as handle:
    df = pickle.load(handle)

# %%
df.head()
# Out:
#                 Decision                                              Texts
# 0  decisions/cp1/1-1.pdf  FCCC/CP/1995/7/Add.1EnglishPage 4I.  DECISIONS...
# 1  decisions/cp1/1-2.pdf  FCCC/CP/1995/7/Add.1EnglishPage 7Decision 2/CP...
# 2  decisions/cp1/1-3.pdf  FCCC/CP/1995/7/Add.1EnglishPage 13Decision 3/C...
# 3  decisions/cp1/1-4.pdf  FCCC/CP/1995/7/Add.1EnglishPage 15Decision 4/C...
# 4  decisions/cp1/1-5.pdf  FCCC/CP/1995/7/Add.1EnglishPage 18Decision 5/C...

# %%
#Now tokenize and normalize words not sentences
df['tokenized_words'] = df['Texts'].apply(lambda x: lucem_illud_2020.word_tokenize(x))
df['normalized_words'] = df['Texts'].apply(lambda x: lucem_illud_2020.normalizeTokens(x, lemma=False))

# %%
keywords = ['transparency','mitigation','adaptation','cooperation','technology','capacity','contribution','effectiveness','information']

# %%
from itertools import chain

taggedDocs = []
for index, row in df.iterrows():
    #Just doing a simple keyword assignment
    docKeywords = [s for s in keywords if s in row['normalized_words']]
    docKeywords.append(row['Decision']) 
    taggedDocs.append(gensim.models.doc2vec.LabeledSentence(words = row['normalized_words'], tags = docKeywords))
df['tagged_description'] = taggedDocs

# %%
df.head()
# Out:
#                 Decision                                              Texts  \
# 0  decisions/cp1/1-1.pdf  FCCC/CP/1995/7/Add.1EnglishPage 4I.  DECISIONS...
# 1  decisions/cp1/1-2.pdf  FCCC/CP/1995/7/Add.1EnglishPage 7Decision 2/CP...
# 2  decisions/cp1/1-3.pdf  FCCC/CP/1995/7/Add.1EnglishPage 13Decision 3/C...
# 3  decisions/cp1/1-4.pdf  FCCC/CP/1995/7/Add.1EnglishPage 15Decision 4/C...
# 4  decisions/cp1/1-5.pdf  FCCC/CP/1995/7/Add.1EnglishPage 18Decision 5/C...
#
#                                      tokenized_words  \
# 0  [FCCC, CP/1995/7, Add.1EnglishPage, 4I., DECIS...
# 1  [FCCC, CP/1995/7, Add.1EnglishPage, 7Decision,...
# 2  [FCCC, CP/1995/7, Add.1EnglishPage, 13Decision...
# 3  [FCCC, CP/1995/7, Add.1EnglishPage, 15Decision...
# 4  [FCCC, CP/1995/7, Add.1EnglishPage, 18Decision...
#
#                                     normalized_words  \
# 0  [fccc, cp/1995/7, add.1englishpage, 4i, decisi...
# 1  [fccc, cp/1995/7, add.1englishpage, 7decision,...
# ...

# %%
#Train a Doc2Vec model
D2V = gensim.models.doc2vec.Doc2Vec(df['tagged_description'], size = 100)
# Out:
# /Users/daphne/opt/anaconda3/lib/python3.7/site-packages/gensim/models/doc2vec.py:574: UserWarning: The parameter `size` is deprecated, will be removed in 4.0.0, use `vector_size` instead.
#   warnings.warn("The parameter `size` is deprecated, will be removed in 4.0.0, use `vector_size` instead.")

# %%
df.shape
# Out:
# (505, 5)

# %%
len(D2V.docvecs)
# Out:
# 514

# %%
D2V.docvecs.most_similar([ D2V['transparency'] ], topn=5 )
# Out:
# [('decisions/cp19/19-12.pdf', 0.7663722038269043),
#  ('decisions/cp13/13-6.pdf', 0.7221767902374268),
#  ('decisions/cp4/4-4.pdf', 0.7136016488075256),
#  ('decisions/cp14/14-5.pdf', 0.6774246692657471),
#  ('decisions/cp20/20-11.pdf', 0.6751117706298828)]

# %%
D2V.docvecs.most_similar([ D2V['effectiveness'] ], topn=10 )
# Out:
# [('decisions/cp19/19-12.pdf', 0.8577699065208435),
#  ('decisions/cp18/18-3.pdf', 0.8303739428520203),
#  ('decisions/cp20/20-2.pdf', 0.800536036491394),
#  ('decisions/cp22/22-6.pdf', 0.793503999710083),
#  ('decisions/cp23/23-2.pdf', 0.782857358455658),
#  ('decisions/cp21/21-2.pdf', 0.7769314050674438),
#  ('decisions/cp15/15-4.pdf', 0.756702721118927),
#  ('decisions/cp24/24-7.pdf', 0.7505034804344177),
#  ('decisions/cp23/23-16.pdf', 0.7450259923934937),
#  ('decisions/cp22/22-25.pdf', 0.7355685234069824)]

# %%
D2V.docvecs.most_similar([ D2V['compliance'] ], topn=10 )
# Out:
# [('decisions/cp7/7-24.pdf', 0.7428483366966248),
#  ('decisions/cp4/4-7.pdf', 0.6787547469139099),
#  ('decisions/cp8/8-25.pdf', 0.6375598907470703),
#  ('decisions/cp17/17-4.pdf', 0.5078482627868652),
#  ('decisions/cp25/25-4.pdf', 0.5057035684585571),
#  ('decisions/cp10/10-17.pdf', 0.496268630027771),
#  ('decisions/cp23/23-8.pdf', 0.4918707013130188),
#  ('decisions/cp24/24-2.pdf', 0.4908358156681061),
#  ('decisions/cp23/23-2.pdf', 0.48815226554870605),
#  ('decisions/cp8/8-22.pdf', 0.47662317752838135)]

# %%
D2V.docvecs.most_similar([ D2V['obligation'] ], topn=10 )
# Out:
# [('decisions/cp24/24-2.pdf', 0.844217836856842),
#  ('decisions/cp20/20-2.pdf', 0.7829680442810059),
#  ('decisions/cp18/18-13.pdf', 0.7810319066047668),
#  ('decisions/cp25/25-4.pdf', 0.7746807932853699),
#  ('decisions/cp23/23-2.pdf', 0.7593925595283508),
#  ('decisions/cp4/4-19.pdf', 0.7545971870422363),
#  ('decisions/cp4/4-18.pdf', 0.7516809701919556),
#  ('decisions/cp1/1-15.pdf', 0.7432981729507446),
#  ('decisions/cp21/21-2.pdf', 0.7393097281455994),
#  ('decisions/cp11/11-13.pdf', 0.7379395365715027)]

# %%
D2V.docvecs.most_similar([ D2V['monitor'] ], topn=10 )
# Out:
# [('decisions/cp19/19-17.pdf', 0.7504518032073975),
#  ('decisions/cp9/9-10.pdf', 0.7440723180770874),
#  ('decisions/cp19/19-10.pdf', 0.7175778150558472),
#  ('decisions/cp23/23-2.pdf', 0.7161500453948975),
#  ('decisions/cp23/23-8.pdf', 0.6883640289306641),
#  ('decisions/cp25/25-4.pdf', 0.679735541343689),
#  ('decisions/cp4/4-5.pdf', 0.6767458319664001),
#  ('decisions/cp17/17-6.pdf', 0.6737838983535767),
#  ('decisions/cp18/18-13.pdf', 0.6571089029312134),
#  ('decisions/cp1/1-7.pdf', 0.6505961418151855)]

# %%
D2V.docvecs.most_similar([ D2V['mitigation'] ], topn=5 )
# Out:
# [('decisions/cp19/19-12.pdf', 0.7722707986831665),
#  ('decisions/cp3/3-9.pdf', 0.7185380458831787),
#  ('decisions/cp20/20-11.pdf', 0.7184346318244934),
#  ('decisions/cp4/4-4.pdf', 0.6881612539291382),
#  ('decisions/cp23/23-12.pdf', 0.687351405620575)]

# %%
D2V.docvecs.most_similar([ D2V['adaptation'] ], topn=5 )
# Out:
# [('decisions/cp22/22-6.pdf', 0.8514227271080017),
#  ('decisions/cp16/16-5.pdf', 0.8029868602752686),
#  ('decisions/cp21/21-4.pdf', 0.7888928651809692),
#  ('decisions/cp19/19-12.pdf', 0.7804055213928223),
#  ('decisions/cp22/22-14.pdf', 0.7583562135696411)]

# %%
D2V.docvecs.most_similar([ D2V['cooperation'] ], topn=5 )
# Out:
# [('decisions/cp13/13-9.pdf', 0.7873120307922363),
#  ('decisions/cp25/25-3.pdf', 0.7872793674468994),
#  ('decisions/cp23/23-2.pdf', 0.7726613283157349),
#  ('decisions/cp18/18-3.pdf', 0.7717608213424683),
#  ('decisions/cp4/4-4.pdf', 0.7701814770698547)]

# %%
D2V.docvecs.most_similar([ D2V['inventory'] ], topn=5 )
# Out:
# [('decisions/cp1/1-2.pdf', 0.8184760808944702),
#  ('decisions/cp4/4-11.pdf', 0.8061454892158508),
#  ('decisions/cp23/23-19.pdf', 0.8038723468780518),
#  ('decisions/cp5/5-6.pdf', 0.7980539798736572),
#  ('decisions/cp6/6-3.pdf', 0.7604166269302368)]

# %%
D2V.docvecs.most_similar([ D2V['paris'] ], topn=10 )
# Out:
# [('decisions/cp7/7-24.pdf', 0.7619063258171082),
#  ('decisions/cp22/22-1.pdf', 0.7564903497695923),
#  ('decisions/cp25/25-9.pdf', 0.6987706422805786),
#  ('decisions/cp7/7-18.pdf', 0.6253008842468262),
#  ('decisions/cp3/3-14.pdf', 0.6048688292503357),
#  ('decisions/cp14/14-6.pdf', 0.5994330644607544),
#  ('decisions/cp4/4-1.pdf', 0.5925281047821045),
#  ('decisions/cp18/18-2.pdf', 0.5894988775253296),
#  ('decisions/cp24/24-11.pdf', 0.5858339667320251),
#  ('decisions/cp22/22-13.pdf', 0.5829497575759888)]

# %% [markdown]
# 3. Visualization

# %%
#Plot the keywords similarities
heatmapMatrix = []
for tagOuter in keywords:
    column = []
    tagVec = D2V.docvecs[tagOuter].reshape(1, -1)
    for tagInner in keywords:
        column.append(sklearn.metrics.pairwise.cosine_similarity(tagVec, D2V.docvecs[tagInner].reshape(1, -1))[0][0])
    heatmapMatrix.append(column)
heatmapMatrix = np.array(heatmapMatrix)

# %%
fig, ax = plt.subplots()
hmap = ax.pcolor(heatmapMatrix, cmap='terrain')
cbar = plt.colorbar(hmap)

cbar.set_label('cosine similarity', rotation=270)
a = ax.set_xticks(np.arange(heatmapMatrix.shape[1]) + 0.5, minor=False)
a = ax.set_yticks(np.arange(heatmapMatrix.shape[0]) + 0.5, minor=False)

a = ax.set_xticklabels(keywords, minor=False, rotation=270)
a = ax.set_yticklabels(keywords, minor=False)

# %%
#Word similarities within decision
targetDocs = df['Decision'][20:30]

heatmapMatrixC = []

for tagOuter in targetDocs:
    column = []
    tagVec = D2V.docvecs[tagOuter].reshape(1, -1)
    for tagInner in keywords:
        column.append(sklearn.metrics.pairwise.cosine_similarity(tagVec, D2V.docvecs[tagInner].reshape(1, -1))[0][0])
    heatmapMatrixC.append(column)
heatmapMatrixC = np.array(heatmapMatrixC)

# %%
fig, ax = plt.subplots()
hmap = ax.pcolor(heatmapMatrixC, cmap='terrain')
cbar = plt.colorbar(hmap)

cbar.set_label('cosine similarity', rotation=270)
a = ax.set_xticks(np.arange(heatmapMatrixC.shape[1]) + 0.5, minor=False)
a = ax.set_yticks(np.arange(heatmapMatrixC.shape[0]) + 0.5, minor=False)

a = ax.set_xticklabels(keywords, minor=False, rotation=270)
a = ax.set_yticklabels(targetDocs, minor=False)

# %%
#Word similarities within decision
targetDocs = df['Decision']

heatmapMatrixC_all = []

for tagOuter in targetDocs:
    column = []
    tagVec = D2V.docvecs[tagOuter].reshape(1, -1)
    for tagInner in keywords:
        column.append(sklearn.metrics.pairwise.cosine_similarity(tagVec, D2V.docvecs[tagInner].reshape(1, -1))[0][0])
    heatmapMatrixC_all.append(column)
heatmapMatrixC_all = np.array(heatmapMatrixC)

fig, ax = plt.subplots(figsize=(35,35))
hmap = ax.pcolor(heatmapMatrixC_all, cmap='terrain')
cbar = plt.colorbar(hmap)

cbar.set_label('cosine similarity', rotation=270)
a = ax.set_xticks(np.arange(heatmapMatrixC_all.shape[1]) + 0.5, minor=False)
a = ax.set_yticks(np.arange(heatmapMatrixC_all.shape[0]) + 0.5, minor=False)

a = ax.set_xticklabels(keywords, minor=False, rotation=270)
a = ax.set_yticklabels(targetDocs, minor=False)

# %%
transpose_all = heatmapMatrixC_all.T

# %%
dec_map = {1:22, 2:18, 3:18,4:21, 5:22, 6:7, 7:41, 8:26, 9:22, 10:18, 11:17, 
           12:10, 13:14,14:10, 15:14, 16:13, 17:20, 18:27, 19:29, 20:25, 
           21:24, 22:26, 23:23, 24:19, 25:19}

# %%
def get_year_avg(heat505):
    avg = []
    for year in dec_map:
        sum_ = 0
        for i in range(1, dec_map[year]+1):
            sum_ += heat505[i]
        avg.append(sum_/ dec_map[year])
        
    return avg

# %%
plt.rcParams["figure.figsize"] = (30,9)
plt.plot(range(25), get_year_avg(transpose_all[0]),color='blue', label = 'transparency',linewidth=4)
plt.plot(range(25), get_year_avg(transpose_all[1]), color='green',label = 'mitigation', linewidth=4)
plt.plot(range(25), get_year_avg(transpose_all[2]),color='yellow', label = 'adaptation', linewidth=4)
plt.plot(range(25), get_year_avg(transpose_all[3]), color='purple',label = 'cooperation', linewidth=4)
plt.plot(range(25), get_year_avg(transpose_all[7]), color='olive',label = 'effectiveness', linewidth=4)


plt.legend()

# %%
targetDocs = df['Decision'].sample(n = 16).sort_index()

heatmapMatrixC = []

for tagOuter in targetDocs:
    column = []
    tagVec = D2V.docvecs[tagOuter].reshape(1, -1)
    for tagInner in keywords:
        column.append(sklearn.metrics.pairwise.cosine_similarity(tagVec, D2V.docvecs[tagInner].reshape(1, -1))[0][0])
    heatmapMatrixC.append(column)
heatmapMatrixC = np.array(heatmapMatrixC)

fig, ax = plt.subplots()
hmap = ax.pcolor(heatmapMatrixC, cmap='terrain')
cbar = plt.colorbar(hmap)

cbar.set_label('cosine similarity', rotation=270)
a = ax.set_xticks(np.arange(heatmapMatrixC.shape[1]) + 0.5, minor=False)
a = ax.set_yticks(np.arange(heatmapMatrixC.shape[0]) + 0.5, minor=False)

a = ax.set_xticklabels(keywords, minor=False, rotation=270)
a = ax.set_yticklabels(targetDocs, minor=False)

# %%
targetDocs = df['Decision'].sample(n = 16).sort_index()

heatmapMatrixC = []

for tagOuter in targetDocs:
    column = []
    tagVec = D2V.docvecs[tagOuter].reshape(1, -1)
    for tagInner in keywords:
        column.append(sklearn.metrics.pairwise.cosine_similarity(tagVec, D2V.docvecs[tagInner].reshape(1, -1))[0][0])
    heatmapMatrixC.append(column)
heatmapMatrixC = np.array(heatmapMatrixC)

fig, ax = plt.subplots()
hmap = ax.pcolor(heatmapMatrixC, cmap='terrain')
cbar = plt.colorbar(hmap)

cbar.set_label('cosine similarity', rotation=270)
a = ax.set_xticks(np.arange(heatmapMatrixC.shape[1]) + 0.5, minor=False)
a = ax.set_yticks(np.arange(heatmapMatrixC.shape[0]) + 0.5, minor=False)

a = ax.set_xticklabels(keywords, minor=False, rotation=270)
a = ax.set_yticklabels(targetDocs, minor=False)

# %%
targetDocs = df['Decision'].sample(n = 25).sort_index()

heatmapMatrixC = []

for tagOuter in targetDocs:
    column = []
    tagVec = D2V.docvecs[tagOuter].reshape(1, -1)
    for tagInner in keywords:
        column.append(sklearn.metrics.pairwise.cosine_similarity(tagVec, D2V.docvecs[tagInner].reshape(1, -1))[0][0])
    heatmapMatrixC.append(column)
heatmapMatrixC = np.array(heatmapMatrixC)

fig, ax = plt.subplots()
hmap = ax.pcolor(heatmapMatrixC, cmap='terrain')
cbar = plt.colorbar(hmap)

cbar.set_label('cosine similarity', rotation=270)
a = ax.set_xticks(np.arange(heatmapMatrixC.shape[1]) + 0.5, minor=False)
a = ax.set_yticks(np.arange(heatmapMatrixC.shape[0]) + 0.5, minor=False)

a = ax.set_xticklabels(keywords, minor=False, rotation=270)
a = ax.set_yticklabels(targetDocs, minor=False)

# %% [markdown]
# ## <span style="color:red">*Exercise 3*</span>
#
# <span style="color:red">Construct cells immediately below this that embed documents related to your final project, then generate meaningful semantic dimensions based on your theoretical understanding of the semantic space (i.e., by subtracting semantically opposite word vectors) and project another set of word vectors onto those dimensions. Interpret the meaning of these projections for your analysis. Which of the dimensions you analyze explain the most variation in the projection of your words and why?
#
# <span style="color:red">***Stretch***: Average together multiple antonym pairs to create robust semantic dimensions. How do word projections on these robust dimensions differ from single-pair dimensions?

# %%
def normalize(vector):
    normalized_vector = vector / np.linalg.norm(vector)
    return normalized_vector

def dimension(model, positives, negatives):
    diff = sum([normalize(model[x]) for x in positives]) - sum([normalize(model[y]) for y in negatives])
    return diff

# %%
#Define my dimensions of interest
substantive = dimension(W2V, ['mitigation','adaptation','inventory'], ['transparency','cooperation','information'])
state_burden = dimension(W2V, ['report','contribution','inventory','party'], ['secretariat','convention','subsidiary'])

# %%
import pandas

def makeDF(model, word_list):
    r = []
    p = []
    for word in word_list:
        r.append(sklearn.metrics.pairwise.cosine_similarity(W2V[word].reshape(1,-1), substantive.reshape(1,-1))[0][0])
        p.append(sklearn.metrics.pairwise.cosine_similarity(W2V[word].reshape(1,-1), state_burden.reshape(1,-1))[0][0])
    df = pandas.DataFrame({'substantive': r, 'state burden': p}, index = word_list)
    return df

# %%
words = ['climate','carbon','sink','party','convention','removal','state','communication',
         'contribution','unfccc','annex','report','monitor','capacity','transfer']

# %%
#Get the projections
pro_df = makeDF(W2V, words)

# %%
def Coloring(Series):
    x = Series.values
    y = x-x.min()
    z = y/y.max()
    c = list(plt.cm.rainbow(z))
    return c

def PlotDimension(ax,df, dim):
    ax.set_frame_on(False)
    ax.set_title(dim, fontsize = 20)
    colors = Coloring(df[dim])
    for i, word in enumerate(df.index):
        ax.annotate(word, (0, df[dim][i]), color = colors[i], alpha = 0.6, fontsize = 12)
    MaxY = df[dim].max()
    MinY = df[dim].min()
    plt.ylim(MinY,MaxY)
    plt.yticks(())
    plt.xticks(())

# %%
fig = plt.figure(figsize = (12,4))
ax1 = fig.add_subplot(121)
PlotDimension(ax1, pro_df, 'substantive')
ax2 = fig.add_subplot(122)
PlotDimension(ax2, pro_df, 'state burden')
plt.show()

# %% [markdown]
# # Exercise 4a

# %%
f = ['adaptation.pdf','capacity_build.pdf','finance.pdf','mitigation.pdf','transfer.pdf','transparency.pdf']
t = ['adaptation','capacity_build','finance','mitigation','transfer','transparency','cbd','cedaw','us_constitution','ramsar','unclos','vclt']
files = ['../week-6/climate_labeled_data/'+pdf for pdf in f]
files+=['international_treaties/'+ pdf for pdf in ['cbd_2.pdf','cedaw.pdf','constitution.pdf','ramsar.pdf','unclos.pdf','vclt.pdf']]

# %%
files
# Out:
# ['../week-6/climate_labeled_data/adaptation.pdf',
#  '../week-6/climate_labeled_data/capacity_build.pdf',
#  '../week-6/climate_labeled_data/finance.pdf',
#  '../week-6/climate_labeled_data/mitigation.pdf',
#  '../week-6/climate_labeled_data/transfer.pdf',
#  '../week-6/climate_labeled_data/transparency.pdf',
#  'international_treaties/cbd_2.pdf',
#  'international_treaties/cedaw.pdf',
#  'international_treaties/constitution.pdf',
#  'international_treaties/ramsar.pdf',
#  'international_treaties/unclos.pdf',
#  'international_treaties/vclt.pdf']

# %%
import textract
def clean_text(file_name):
    '''
    Open a pdf file, extract the text and return it.
    
    Input:
       file_name, string
    Output:
       string of text
          
    '''
    text = textract.process(file_name).decode('utf-8')
    text = text.replace("\n", "")
    text = text.replace("■", "")
    print(file_name, 'done')
    return text

# %%
import pandas as pd
out_df = pd.DataFrame()

# %%
out_df['topic'] = t

# %%
out_df['text'] = [clean_text(f) for f in files]
# Out:
# ../week-6/climate_labeled_data/adaptation.pdf done
# ../week-6/climate_labeled_data/capacity_build.pdf done
# ../week-6/climate_labeled_data/finance.pdf done
# ../week-6/climate_labeled_data/mitigation.pdf done
# ../week-6/climate_labeled_data/transfer.pdf done
# ../week-6/climate_labeled_data/transparency.pdf done
# international_treaties/cbd_2.pdf done
# international_treaties/cedaw.pdf done
# international_treaties/constitution.pdf done
# international_treaties/ramsar.pdf done
# international_treaties/unclos.pdf done
# international_treaties/vclt.pdf done

# %%
out_df
# Out:
#               topic                                               text
# 0        adaptation  12trepahC92UNFCCC HandbookAdapting to climate ...
# 1    capacity_build  17trepahCUNFCCC HandbookBuilding capacity Stri...
# 2           finance  13trepahC114UNFCCC HandbookProviding financial...
# 3        mitigation  11trepahC74UNFCCC HandbookMitigating climate c...
# 4          transfer  14trepahCDeveloping and transferring technolog...
# 5      transparency  accurate, consistent  and Communicating inform...
# 6               cbd  Secretariat of the Convention on Biological Di...
# 7             cedaw  Convention on the Elimination of All Forms of ...
# 8   us_constitution  We the People of the United States, in Order t...
# 9            ramsar  Convention on Wetlands of International Import...
# 10           unclos  25PREAMBLEThe States Parties to this Conventio...
# 11             vclt              Vienna Convention on the Law of Tr...

# %%
#Now tokenize and normalize this dataframe
out_df['tokenized_sents'] = out_df['text'].apply(lambda x: [lucem_illud_2020.word_tokenize(s) for s in lucem_illud_2020.sent_tokenize(x)])
out_df['normalized_sents'] = out_df['tokenized_sents'].apply(lambda x: [lucem_illud_2020.normalizeTokens(s, lemma=False) for s in x])

# %%
def adprob(ad, model):
    sen_scores = model.score(ad, len(ad))
    ad_score = sen_scores.mean()
    return ad_score

# %%
df
# Out:
#                      Decision  \
# 0       decisions/cp1/1-1.pdf
# 1       decisions/cp1/1-2.pdf
# 2       decisions/cp1/1-3.pdf
# 3       decisions/cp1/1-4.pdf
# 4       decisions/cp1/1-5.pdf
# ..                        ...
# 500  decisions/cp25/25-15.pdf
# 501  decisions/cp25/25-16.pdf
# 502  decisions/cp25/25-17.pdf
# 503  decisions/cp25/25-18.pdf
# 504  decisions/cp25/25-19.pdf
#
#                                                  Texts  \
# 0    FCCC/CP/1995/7/Add.1EnglishPage 4I.  DECISIONS...
# 1    FCCC/CP/1995/7/Add.1EnglishPage 7Decision 2/CP...
# 2    FCCC/CP/1995/7/Add.1EnglishPage 13Decision 3/C...
# 3    FCCC/CP/1995/7/Add.1EnglishPage 15Decision 4/C...
# 4    FCCC/CP/1995/7/Add.1EnglishPage 18Decision 5/C...
# ..                                                 ...
# 500  FCCC/CP/2019/13/Add.2     Decision 15/CP.25   ...
# 501  FCCC/CP/2019/13/Add.2     Decision 16/CP.25   ...
# 502  FCCC/CP/2019/13/Add.2     Decision 17/CP.25   ...
# ...

# %%
#Change the specification 
W2V4 = gensim.models.word2vec.Word2Vec(df2['normalized_sents'].sum(), hs=1, negative=0)

# %%
#Now apply the function to every treaty
out_df['likelihood'] = out_df['normalized_sents'].apply(lambda x: adprob(x, W2V4))

# %%
# rank treaty in similarity
for ad in out_df.sort_values(by = 'likelihood', ascending = False)['topic']:
    print (ad + '\n\n')
# Out:
# transparency
#
#
# transfer
#
#
# mitigation
#
#
# finance
#
#
# vclt
#
#
# adaptation
#
#
# cbd
#
#
# capacity_build
#
#
# unclos
#
#
# us_constitution
#
#
# ramsar
#
#
# cedaw
